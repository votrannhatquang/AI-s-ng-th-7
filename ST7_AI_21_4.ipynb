# %% [markdown]
# <a href="https://colab.research.google.com/github/votrannhatquang/AI-s-ng-th-7/blob/main/ST7_AI_21_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 46.5 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename='/content/drive/MyDrive/anhlop.jpg'
img=plt.imread(filename)
plt.imshow(img)
detector=MTCNN()
faces=detector.detect_faces(img)
for face in faces:
  print(face)
# Out:
# ...
# 7/7 [==============================] - 0s 3ms/step
# {'box': [1368, 906, 68, 88], 'confidence': 1.0, 'keypoints': {'left_eye': (1390, 942), 'right_eye': (1422, 941), 'nose': (1408, 961), 'mouth_left': (1391, 970), 'mouth_right': (1422, 970)}}
# {'box': [665, 905, 82, 102], 'confidence': 0.9999996423721313, 'keypoints': {'left_eye': (691, 944), 'right_eye': (729, 949), 'nose': (708, 966), 'mouth_left': (687, 980), 'mouth_right': (722, 983)}}
# {'box': [1967, 928, 84, 99], 'confidence': 0.9999938011169434, 'keypoints': {'left_eye': (1987, 964), 'right_eye': (2029, 964), 'nose': (2008, 984), 'mouth_left': (1988, 1002), 'mouth_right': (2025, 1003)}}
# {'box': [1686, 815, 40, 48], 'confidence': 0.9999912977218628, 'keypoints': {'left_eye': (1701, 833), 'right_eye': (1719, 833), 'nose': (1712, 842), 'mouth_left': (1702, 852), 'mouth_right': (1718, 852)}}
# ...

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename='/content/drive/MyDrive/argentina-vo-dich-world-cup-5406.jpg'
img=plt.imread(filename)
plt.imshow(img)
detector=MTCNN()
faces=detector.detect_faces(img)
ax=plt.gca()

for face in faces:
  x,y,width,height=face['box']
  rect=plt.Rectangle((x,y),width,height,fill=False,color='red')
  ax.add_patch(rect)
  plt.savefig('/content/drive/MyDrive/anh_test/AI_anh.jpg')

  for key,value in face['keypoints'].items():
    dot=plt.Circle(value,radius=2,color='red')
    ax.add_patch(dot)
    plt.savefig('/content/drive/MyDrive/anh_test/AI_anh1.jpg')
plt.show()
# Out:
# ...
# 4/4 [==============================] - 0s 4ms/step

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN
filename='/content/drive/MyDrive/anh 9.jpg'
img=plt.imread(filename)
plt.imshow(img)
detector=MTCNN()
faces=detector.detect_faces(img)
ax=plt.gca()

for face in faces:
  x,y,width,height=face['box']
  rect=plt.Rectangle((x,y),width,height,fill=False,color='red')
  ax.add_patch(rect)
  

  for key,value in face['keypoints'].items():
    dot=plt.Circle(value,radius=2,color='red')
    ax.add_patch(dot)
    plt.savefig('/content/drive/MyDrive/anh_test/AI_anh4.jpg')
plt.show()
# Out:
# ...
# 8/8 [==============================] - 0s 3ms/step

# %%
import matplotlib.pyplot as plt
from mtcnn import MTCNN

def draw_faces(filename,result_list):
  data=plt.imread(filename)
  for i in range(len(result_list)):
    x1,y1,width,height=result_list[i]['box']
    x2,y2=x1+width,y1+height
    plt.subplot(1,len(result_list),i+1)
    plt.axis('off')
    plt.imshow(data[y1:y2,x1:x2])
    plt.savefig('/content/drive/MyDrive/anh_test/anhnguoidien.jpg')
plt.show()

filename='/content/drive/MyDrive/anhlop.jpg'
img=plt.imread(filename)
plt.imshow(img)
detector=MTCNN()
faces=detector.detect_faces(img)
draw_faces(filename,faces)
# Out:
# ...
# 7/7 [==============================] - 0s 3ms/step
# <ipython-input-28-08deeb514398>:9: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,len(result_list),i+1)

# %%
pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

model = ResNet50(weights='imagenet')

img_path = '/content/drive/MyDrive/cay10-1442480776.jpg'
img = image.load_img(img_path, target_size=(224, 224))
plt.imshow(img)
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)
# decode the results into a list of tuples (class, description, probability)
# (one such list for each sample in the batch)
print('Predicted:', decode_predictions(preds, top=3)[0])
# Predicted: [(u'n02504013', u'Indian_elephant', 0.82658225), (u'n01871265', u'tusker', 0.1122357), (u'n02504458', u'African_elephant', 0.061040461)]
# Out:
# WARNING:tensorflow:5 out of the last 61 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7ff96c0775e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 866ms/step
# Predicted: [('n02190166', 'fly', 0.15706952), ('n02264363', 'lacewing', 0.11887954), ('n02206856', 'bee', 0.06303718)]

# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import preprocess_input,decode_predictions
import numpy as np

model = VGG16(weights='imagenet', include_top=True)

img_path = '/content/drive/MyDrive/meo_vang3.jpg'
img = image.load_img(img_path, target_size=(224, 224))
plt.imshow(img)
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

features = model.predict(x)
print('Predicted:', decode_predictions(features, top=3)[0])
# Out:
# ...
# 1/1 [==============================] - 0s 158ms/step
# Predicted: [('n02123045', 'tabby', 0.2640062), ('n02124075', 'Egyptian_cat', 0.14515516), ('n02123159', 'tiger_cat', 0.14508167)]

# %%
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg19 import preprocess_input,decode_predictions
from tensorflow.keras.models import Model
import numpy as np

base_model = VGG19(weights='imagenet', include_top=True )
model = Model(inputs=base_model.input, outputs=base_model.get_layer('block4_pool').output)

img_path = '/content/drive/MyDrive/ta-con-ca-vang-dang-boi-trong-be-ca.jpg'
img = image.load_img(img_path, target_size=(224, 224))
plt.imshow(img)
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

block4_pool_features = model.predict(x)
print('Predicted:', decode_predictions(block4_pool_features, top=3)[0])
# Out:
# 1/1 [==============================] - 0s 152ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-9750fb282e27> in <cell line: 18>()
#      16
#      17 block4_pool_features = model.predict(x)
# ---> 18 print('Predicted:', decode_predictions(block4_pool_features, top=3)[0])
#
# /usr/local/lib/python3.9/dist-packages/keras/applications/vgg19.py in decode_predictions(preds, top)
#     270 @keras_export("keras.applications.vgg19.decode_predictions")
#     271 def decode_predictions(preds, top=5):
# --> 272     return imagenet_utils.decode_predictions(preds, top=top)
#     273
#     274
#
# /usr/local/lib/python3.9/dist-packages/keras/applications/imagenet_utils.py in decode_predictions(preds, top)
#     151
#     152     if len(preds.shape) != 2 or preds.shape[1] != 1000:
# --> 153         raise ValueError(
# ...

# %%
from tensorflow.keras.applications.vgg19 import VGG19, preprocess_input, decode_predictions
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# Load the VGG19 model
model = VGG19(weights='imagenet')

# Load and preprocess the image
img_path = '/content/drive/MyDrive/a4d51c2d-5a58-44be-b3f2-579db0b10d32.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# Use the VGG19 model to classify the image and decode the predictions
preds = model.predict(x)
decoded_preds = decode_predictions(preds, top=3)[0]

# Print the decoded predictions
for pred in decoded_preds:
    print("Predicted Class: {}, Probability: {:.2f}%".format(pred[1], pred[2]*100))
    
# Display the image
plt.imshow(img)
# Out:
# 1/1 [==============================] - 1s 560ms/step
# Predicted Class: sports_car, Probability: 58.67%
# Predicted Class: convertible, Probability: 23.79%
# Predicted Class: car_wheel, Probability: 6.07%
